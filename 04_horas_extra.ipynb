# %%
#Sobrecarga por horas extras - Detectar equipos con niveles sostenidos de horas extras

import pandas as pd
import matplotlib.pyplot as plt

eventos = pd.read_excel('/content/eventos_rrhh2.xlsx')

#Agrupamos áreas por horas extra

horas_extra = empleados.groupby('area')['horas_extra'].mean().sort_values(ascending=False)

horas_extra.plot(kind='bar')
plt.title('Horas extra promedio por área')
plt.ylabel('Horas promedio')
plt.xlabel('Área')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('horas_extra_area.png')
plt.show()
